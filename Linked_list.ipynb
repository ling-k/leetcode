# %% [markdown]
# # Linked List

# %% [markdown]
# ## What is Linked list:
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 34. Reverse Linked List (iterative)
# [Leetcode: 206. Reverse Linked List](https://leetcode.com/problems/reverse-linked-list/)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: ListNode) -> ListNode: 
        if not head or not head.next: 
            return head  
        
        return self.reverseRec(head) 
    
    def reverseIterative(self, head): 
        prev_node = None 
        cur_node = head 
        
        while cur_node: 
            next_node = cur_node.next 
            cur_node.next = prev_node 
            prev_node = cur_node 
            cur_node = next_node 
        return prev_node 
    
    def reverseRec(self, head): 
        # base case: return the last head 
        if not head.next: 
            return head 
        
        # assume we got the reversed subHead
        subHead = self.reverseRec(head.next) 
        # how do we combine head and subHead 
        head.next.next = head 
        head.next = None 
        
        return subHead

# %% [markdown]
# ## 876. Middle of the Linked List
# [Leetcode: 876. Middle of the Linked List](https://leetcode.com/problems/middle-of-the-linked-list/)
#
# ![image.png](attachment:image.png)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def middleNode(self, head: Optional[ListNode]) -> Optional[ListNode]: 
        slow, fast = head, head 
        while fast and fast.next: 
            slow = slow.next 
            fast = fast.next.next 
            
        return slow

# %% [markdown]
# ## 141. Linked List Cycle
# [Leetcode: 141. Linked List Cycle](https://leetcode.com/problems/linked-list-cycle/)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def hasCycle(self, head) -> bool:
        if head is None: 
            return False 
        
        fast, slow = head, head 
        while fast is not None and fast.next is not None: 
            fast = fast.next.next 
            slow = slow.next 
            if slow == fast: 
                return True 
        
        return False

# %% [markdown]
# ## 146. LRU Cache
# [Leetcode: 146. LRU Cache](https://leetcode.com/problems/lru-cache/)
#
# What is Least recently used (LRU):
# [Wiki:](https://en.wikipedia.org/wiki/Cache_replacement_policies#Least_recently_used_(LRU))
# Cache can be seen as a limited amount of high speed memory located close to CPU. Due to its limited size, one has to decide which information to discard when it's full, in order to make room for new infromation.
#
# Cache replacement policies must choose which items to discard when the cache is full. Least recently used (LRU) is one of such policies. Briefly speaking, it discards the least recently used items first.

# %% [markdown]
# ### Implementation
# ```
# LRUCache lRUCache = new LRUCache(2);
# lRUCache.put(1, 1); // cache is {1=1}
# lRUCache.put(2, 2); // cache is {1=1, 2=2}
# lRUCache.get(1);    // return 1
# lRUCache.put(3, 3); // LRU key was 2, evicts key 2, cache is {1=1, 3=3}
# lRUCache.get(2);    // returns -1 (not found)
# lRUCache.put(4, 4); // LRU key was 1, evicts key 1, cache is {4=4, 3=3}
# lRUCache.get(1);    // return -1 (not found)
# lRUCache.get(3);    // return 3
# lRUCache.get(4);    // return 4
# ```
# To implement LRU, we first build the basic backbone.

# %% [markdown]
# ```ruby
# require 'redcarpet'
# markdown = Redcarpet.new("Hello World!")
# puts markdown.to_html
# ```

# %%
class LRUCache:

    def __init__(self, capacity: int):
        pass 
        

    def get(self, key: int) -> int: 
        
        return 1 
        

    def put(self, key: int, value: int) -> None: 
        pass 
    
    def discard(self, key, value): 
        pass 
        


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)
lru = LRUCache(4)
lru.get(3)
# Out:
# 1

# %% [markdown]
# We then implement the first version of LRU with only basic functions. For example, we implement put functions without considering if the key exists or not; we implement discard function with specified key or value, etc. All in all, this version just realizes the simple and naive functions.

# %%
class Node: 
    def __init__(self, key=-1, val=-1, nxt=None, prv=None): 
        self.key = key 
        self.val = val 
        self.next = nxt 
        self.prev = prv 

class DoublyLinkedList: 
    def __init__(self): 
        self.head = None 
        self.tail = None 


class LRUCache:

    def __init__(self, capacity: int):
        self.cap = capacity 
        self.items = {} 
        self.ll = DoublyLinkedList() 

    def get(self, key: int) -> int: 
        
        
        return self.items[key].val 
        

    def put(self, key: int, value: int) -> None: 
        self.items[key] = Node(key, value) 
    
    
    def discard(self, key): 
        
        del self.items[key]
        


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)
lru = LRUCache(4)
lru.put(3, 3) 
lru.put(2, 2) 
print('get 2:', lru.get(2)) 
print('number of items in the lru:', len(lru.items))
lru.discard(3) 
print('number of items in the lru:', len(lru.items))
# Out:
# get 2: 2
# number of items in the lru: 2
# number of items in the lru: 1

# %% [markdown]
# Now that we have the first version of LRU, we consider more carefully and add more functions to it.

# %%
class Node: 
    def __init__(self, key=-1, val=-1, nxt=None, prv=None): 
        self.key = key 
        self.val = val 
        self.next = nxt 
        self.prev = prv 

class DoublyLinkedList: 
    def __init__(self): 
        self.head = None 
        self.tail = None 
    
    def remove(self, node): 
        pass 

    def appendleft(self, node):
        # Makes node the new head (appends left) 
        pass 
    def pop(self, node): 
        # Removing tail and reassigning tail to the previous node, then we return the old tail
        pass 

class LRUCache:

    def __init__(self, capacity: int):
        self.cap = capacity 
        self.items = {} 
        # Linkedlist will hold nodes in the following order: Most recent -> ... -> Least recent
        self.ll = DoublyLinkedList() 

    def get(self, key: int) -> int: 
        if key in self.items: 
            # Before returning the value, we update position of the element in the linkedlist
            # remove the node from the linked list 
            self.ll.remove(self.items[key]) 
            # make it to be the head, indicating it has been most recently used 
            self.ll.appendleft(self.items[key]) 
            
            return self.items[key].val 
        
        return -1 
        

    def put(self, key: int, value: int) -> None:  
        if key in self.items: 
            # Remove from linked list if node exists, because we will later appendleft the NEW node
            self.ll.remove(self.items[key])  
            
        # Create new node, then add and appenleft
        self.items[key] = Node(key, value) 
        self.ll.appendleft(self.items[key]) 
        
        
        # Check if we have more elements than capacity, delete LRU from linked list and dictionary
        if len(self.items) > self.cap: 
            # pop (delete) from linked list and delete from items. 
            del self.items[self.ll.pop().key] 
    
    
    def discard(self, key): 
        
        del self.items[key]
        

lru = LRUCache(4)
lru.put(3, 3) 
lru.put(2, 2) 
print('get 2:', lru.get(2)) 
print('number of items in the lru:', len(lru.items))
lru.discard(3) 
print('number of items in the lru:', len(lru.items))
# Out:
# get 2: 2
# number of items in the lru: 2
# number of items in the lru: 1

# %% [markdown]
# Now that we think carefully about the LRU functions put() and get(), we have finished the LRU class. Next, we implement the remove(), pop(), and appendleft() function for DoublyLinkedList class.

# %%
class Node: 
    def __init__(self, key=-1, val=-1, nxt=None, prv=None): 
        self.key = key 
        self.val = val 
        self.next = nxt 
        self.prev = prv 

class DoublyLinkedList: 
    def __init__(self): 
        self.head = None 
        self.tail = None 
    
    def remove(self, node): 
        if node == self.head == self.tail: 
            # only one node 
            self.head = self.tail = None
        elif node == self.head:
            self.popleft()
        elif node == self.tail:
            self.pop()
        else:
            node.prev.next = node.next  
            node.next.prev = node.prev


    def appendleft(self, node):
        # Makes node the new head (appends left) 
        if self.head: 
            node.next = self.head
            self.head.prev = node 
            self.head = node
        else:
            self.head = self.tail = node
         
    def pop(self): 
        # Removing tail and reassigning tail to the previous node, then we return the old tail
        oldTail = self.tail 
        self.tail = self.tail.prev 
        self.tail.next = None 
        
        return oldTail
    
    def popleft(self):
        # Removing head and reassigning head to the next node
        self.head, self.head.prev = self.head.next, None


class LRUCache:

    def __init__(self, capacity: int):
        self.cap = capacity 
        self.items = {} 
        # Linkedlist will hold nodes in the following order: Most recent -> ... -> Least recent
        self.ll = DoublyLinkedList() 

    def get(self, key: int) -> int: 
        if key in self.items: 
            # Before returning the value, we update position of the element in the linkedlist
            # remove the node from the linked list 
            self.ll.remove(self.items[key]) 
            # make it to be the head, indicating it has been most recently used 
            self.ll.appendleft(self.items[key]) 
            
            return self.items[key].val 
        
        return -1 
        

    def put(self, key: int, value: int) -> None:  
        if key in self.items: 
            # Remove from linked list if node exists, because we will later appendleft the NEW node
            self.ll.remove(self.items[key])  
            
        # Create new node, then add and appenleft
        self.items[key] = Node(key, value) 
        self.ll.appendleft(self.items[key]) 
        
        # Check if we have more elements than capacity, delete LRU from linked list and dictionary
        if len(self.items) > self.cap: 
            # pop (delete) from linked list and delete from items. 
            del self.items[self.ll.pop().key] 
    
    
#     def discard(self, key): 
        
#         del self.items[key]
        

lru = LRUCache(4)
lru.put(3, 3) 
lru.put(2, 2) 
print('get 2:', lru.get(2)) 
print('number of items in the lru:', len(lru.items))
# lru.discard(3) 
print('number of items in the lru:', len(lru.items))
# Out:
# get 2: 2
# number of items in the lru: 2
# number of items in the lru: 2
